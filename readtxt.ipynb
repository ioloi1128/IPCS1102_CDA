# %% [markdown]
# <a href="https://colab.research.google.com/github/ioloi1128/CDA/blob/main/readtxt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd

# %%
#path = r'/content/drive/MyDrive/Colab_data/summer_index.txt'

df = pd.read_csv(r'/content/drive/MyDrive/Colab_data/summer_index.txt', header=0, delim_whitespace=True)
print(df)
# Out:
#      year  TCupper     WYI  Somali   WNPSMI
# 0    1368   10.079 -17.399  20.073   77.759
# 1    1369   41.057  13.460  30.108   -6.574
# 2    1370  -60.472 -60.324 -14.929   86.261
# 3    1371  -54.435   1.099 -34.044  -26.335
# 4    1372   54.271  32.388  15.041  -44.853
# ..    ...      ...     ...     ...      ...
# 534  1907  -34.084 -35.752 -16.210   14.205
# 535  1908   44.956   7.319 -37.023   50.983
# 536  1909   26.192  32.458 -27.163  -41.252
# 537  1910  130.672  27.005  98.421  -35.711
# 538  1911  146.205  96.130  56.998 -102.080
#
# [539 rows x 5 columns]

# %%
df.plot(x ='year', y='Somali', kind = 'line')
