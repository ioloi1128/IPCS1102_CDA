# %% [markdown]
# <a href="https://colab.research.google.com/github/ioloi1128/CDA/blob/main/CDA_paleo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd

# %%
# !pip install xarray
import xarray as xr
from matplotlib import pyplot as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df = pd.read_csv(r'/content/drive/MyDrive/Colab_data/paleo/summer_index.1600-1911.txt', header=0, delim_whitespace=True)
print(df)
# Out:
#      year  TCupper     WYI  Somali   WNPSMI
# 0    1600   -7.789  -2.556  13.432  -19.917
# 1    1601 -117.750 -65.629 -46.890    3.484
# 2    1602   17.031  43.582  -3.739  -95.429
# 3    1603  118.865  29.789  41.898    3.239
# 4    1604   96.543  23.617  44.429    7.407
# ..    ...      ...     ...     ...      ...
# 307  1907  -34.084 -35.752 -16.210   14.205
# 308  1908   44.956   7.319 -37.023   50.983
# 309  1909   26.192  32.458 -27.163  -41.252
# 310  1910  130.672  27.005  98.421  -35.711
# 311  1911  146.205  96.130  56.998 -102.080
#
# [312 rows x 5 columns]

# %%
df.plot(x ='year', y='Somali', kind = 'line')

# %%
df_year = df.year
df_somali = df.Somali

df_year
# Out:
# 0      1600
# 1      1601
# 2      1602
# 3      1603
# 4      1604
#        ...
# 307    1907
# 308    1908
# 309    1909
# 310    1910
# 311    1911
# Name: year, Length: 312, dtype: int64

# %%
df_somali = df.Somali
df_somali_mean = df_somali.mean()
df_somali_anom = df_somali - df_somali_mean

# %%
df_somali_anom = df_somali_anom.to_xarray()
df_somali_anom
# Out:
# <xarray.DataArray 'Somali' (index: 312)>
# array([ 8.89176603e+00, -5.14302340e+01, -8.27923397e+00,  3.73577660e+01,
#         3.98887660e+01,  4.22937660e+01, -1.22312340e+01, -9.36233974e-01,
#         2.03477660e+01, -7.63942340e+01, -6.15232340e+01, -2.62402340e+01,
#         3.08377660e+01, -7.13323397e+00, -3.30023397e+00, -3.69572340e+01,
#         1.66077660e+01, -6.25042340e+01,  4.81967660e+01, -5.26922340e+01,
#        -8.16723397e+00, -1.02732340e+01, -1.32902340e+01,  3.47337660e+01,
#         4.94257660e+01,  4.50776603e+00, -6.03723397e+00, -6.65123397e+00,
#         1.41067660e+01, -1.69762340e+01, -2.74233974e-01, -6.63223397e+00,
#         4.63697660e+01, -4.06202340e+01, -2.68662340e+01, -3.66492340e+01,
#         1.89957660e+01, -4.90862340e+01, -4.40222340e+01, -2.79072340e+01,
#        -8.59122340e+01, -5.94452340e+01,  3.86247660e+01,  3.67967660e+01,
#        -3.52012340e+01,  1.14947660e+01,  4.82587660e+01,  3.47660256e-02,
# ...

# %%
ds_prec = xr.open_dataset("/content/drive/MyDrive/Colab_data/paleo/preci_summer.1600-1911.nc")

ds_prec = ds_prec.sel(time=slice('1650', '1700'))
ds_prec.load()
ds_prec
# Out:
# /usr/local/lib/python3.7/dist-packages/xarray/conventions.py:520: SerializationWarning: variable 'preci' has multiple fill values {9.96921e+36, -9.96921e+36}, decoding all values to NaN.
#   decode_timedelta=decode_timedelta,
# <xarray.Dataset>
# Dimensions:  (time: 50, lat: 49, lon: 53)
# Coordinates:
#   * time     (time) float64 1.65e+03 1.651e+03 1.652e+03 ... 1.698e+03 1.699e+03
#   * lat      (lat) float32 18.25 18.75 19.25 19.75 ... 40.75 41.25 41.75 42.25
#   * lon      (lon) float32 98.25 98.75 99.25 99.75 ... 122.8 123.2 123.8 124.2
# Data variables:
#     preci    (time, lat, lon) float32 nan nan nan nan nan ... nan nan 0.1934 nan

# %%
ds_mean=ds_prec['preci'].mean('time')
ds_mean
# Out:
# <xarray.DataArray 'preci' (lat: 49, lon: 53)>
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [       nan,        nan,        nan, ..., 0.04664335,        nan,
#                nan],
#        [       nan,        nan,        nan, ..., 0.04572847,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan, 0.0345481 ,
#                nan]], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 18.25 18.75 19.25 19.75 ... 40.75 41.25 41.75 42.25
#   * lon      (lon) float32 98.25 98.75 99.25 99.75 ... 122.8 123.2 123.8 124.2

# %%
ds_mean.plot()
